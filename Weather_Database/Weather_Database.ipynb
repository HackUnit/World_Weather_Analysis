# %%
# 1. Created folder called Weather_Database.

# 2. Created a new Jupyter Notebook file to retrieve the weather data and named it Weather_Database.ipynb

# Import dependencies

from citipy import citipy

import pandas as pd

import numpy as np

import json

import requests

import time

from config import weather_api_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

# %%
# Add lat and long to a list

coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.

# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:

    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.

    if city not in cities:

        cities.append(city)

# %%
# 5. Perform OpenWeatherMap API call.

url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")


# Create counters.

record_count = 1

set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):


    # Group citites in sets of 50 for logging purposes.

    if (i % 50 == 0 and i >= 50):

        set_count += 1

        record_count = 1

        time.sleep(60)


    # Create endpoint URL with each city.

    city_url = url + "&q=" + city.replace(" ","+")


    # Log the URL, record, and set numbers and the city.

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.

    record_count += 1


    # Run an API request for each of the cities.

    try:

        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]

        city_country = city_weather["sys"]["country"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        weather_desc = str(city_weather["weather"][0]["description"])
    
        
        # Append the city information into city_data list.
        
        city_data.append({
                        "City": city.title(),

                        "Country": city_country,

                        "Lat": city_lat,
        
                        "Lng": city_lng,
        
                        "Max Temp": city_max_temp,
        
                        "Humidity": city_humidity,
        
                        "Cloudiness": city_clouds,
        
                        "Wind Speed": city_wind,
        
                        "Weather Description": weather_desc})

# If an error is experienced, skip the city.
    
    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | ambon
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | cherskiy
# Processing Record 5 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | beyneu
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | roma
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | tuatapere
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | hobyo
# Processing Record 16 of Set 1 | aswan
# Processing Record 17 of Set 1 | olafsvik
# Processing Record 18 of Set 1 | ternate
# Processing Record 19 of Set 1 | luderitz
# Processing Record 20 of Set 1 | sur
# Processing Record 21 of Set 1 | daryapur
# ...

# %%
# Check numer of cities
len(city_data)
# Out:
# 669

# %%
# 7. Add data to a new DataFrame
weather_data_df = pd.DataFrame(city_data)

# Reorder the columns to look like example

new_weather_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

weather_data_df = weather_data_df[new_weather_order]

weather_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Longyearbyen      SJ  78.2186   15.6401     49.84        87          75
# 1         Ambon      ID  -3.6954  128.1814     76.23        16          20
# 2      Cherskiy      RU  68.7500  161.3000     47.28        45          99
# 3        Dikson      RU  73.5069   80.5464     43.18        93         100
# 4        Beyneu      KZ  45.3167   55.2000     86.27        33          91
# 5      Victoria      HK  22.2855  114.1577     85.32        82           0
# 6          Roma      US  43.2128  -75.4557     83.88        67          75
# 7   Port Alfred      ZA -33.5906   26.8910     57.18        77           0
# 8     Tuatapere      NZ -46.1333  167.6833     44.46        91          99
# 9       Ushuaia      AR -54.8000  -68.3000     29.86        93          75
#
#    Wind Speed Weather Description
# 0        3.44       broken clouds
# 1        8.05          few clouds
# 2       11.86     overcast clouds
# ...

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).

output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
