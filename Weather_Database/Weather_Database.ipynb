# %%
# 1. Created folder called Weather_Database.

# 2. Created a new Jupyter Notebook file to retrieve the weather data and named it Weather_Database.ipynb

# Import dependencies

from citipy import citipy

import pandas as pd

import numpy as np

import json

import requests

import time

from config import weather_api_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

# %%
# Add lat and long to a list

coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.

# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:

    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.

    if city not in cities:

        cities.append(city)

# %%
# 5. Perform OpenWeatherMap API call.

url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")


# Create counters.

record_count = 1

set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):


    # Group citites in sets of 50 for logging purposes.

    if (i % 50 == 0 and i >= 50):

        set_count += 1

        record_count = 1

        time.sleep(60)


    # Create endpoint URL with each city.

    city_url = url + "&q=" + city.replace(" ","+")


    # Log the URL, record, and set numbers and the city.

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.

    record_count += 1


    # Run an API request for each of the cities.

    try:

        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        weather_desc = str(city_weather["weather"][0]["description"])
    
        
        # Append the city information into city_data list.
        
        city_data.append({
                        "City": city.title(),

                        "Lat": city_lat,
        
                        "Lng": city_lng,
        
                        "Max Temp": city_max_temp,
        
                        "Humidity": city_humidity,
        
                        "Cloudiness": city_clouds,
        
                        "Wind Speed": city_wind,
        
                        "Weather Description": weather_desc})

# If an error is experienced, skip the city.
    
    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | antofagasta
# Processing Record 2 of Set 1 | mildura
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | acapulco
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | ostrovnoy
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | teya
# Processing Record 14 of Set 1 | mount pleasant
# Processing Record 15 of Set 1 | tuatapere
# Processing Record 16 of Set 1 | te anau
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | port lincoln
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | price
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | dogondoutchi
# Processing Record 25 of Set 1 | tambopata
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | tigil
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | saint-michel-des-saints
# Processing Record 30 of Set 1 | vestmannaeyjar
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | hwange
# Processing Record 33 of Set 1 | soyo
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | villa rica
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | imbituba
# Processing Record 39 of Set 1 | matola
# Processing Record 40 of Set 1 | blagoyevo
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | primero de marzo
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | elko
# Processing Record 47 of Set 1 | buin
# Processing Record 48 of Set 1 | kozhva
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | vagur
# Processing Record 3 of Set 2 | benesat
# Processing Record 4 of Set 2 | araouane
# Processing Record 5 of Set 2 | den helder
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | novovarshavka
# Processing Record 8 of Set 2 | kahului
# Processing Record 9 of Set 2 | acajutla
# Processing Record 10 of Set 2 | katsuura
# Processing Record 11 of Set 2 | provideniya
# Processing Record 12 of Set 2 | santa paula
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | pevek
# Processing Record 15 of Set 2 | sept-iles
# Processing Record 16 of Set 2 | pangkalanbuun
# Processing Record 17 of Set 2 | yining
# Processing Record 18 of Set 2 | iranshahr
# Processing Record 19 of Set 2 | keskin
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | yumen
# Processing Record 22 of Set 2 | mangrol
# Processing Record 23 of Set 2 | buchanan
# Processing Record 24 of Set 2 | tommot
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | presidente epitacio
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | kadiri
# Processing Record 31 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 2 | grandview
# Processing Record 33 of Set 2 | paamiut
# Processing Record 34 of Set 2 | taltal
# Processing Record 35 of Set 2 | zelenoborsk
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | talnakh
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | tahlequah
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | gamba
# Processing Record 45 of Set 2 | tadine
# Processing Record 46 of Set 2 | clyde river
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | vostok
# Processing Record 50 of Set 2 | komsomolskiy
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | hofn
# Processing Record 3 of Set 3 | umm lajj
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | sassandra
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | sorong
# Processing Record 9 of Set 3 | hobyo
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | adrar
# Processing Record 12 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 13 of Set 3 | okhotsk
# Processing Record 14 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 15 of Set 3 | portoferraio
# Processing Record 16 of Set 3 | jaitaran
# Processing Record 17 of Set 3 | tasiilaq
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | iquique
# Processing Record 20 of Set 3 | arica
# Processing Record 21 of Set 3 | bairiki
# Processing Record 22 of Set 3 | korsakovo
# Processing Record 23 of Set 3 | changtu
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 3 | the valley
# Processing Record 26 of Set 3 | baykit
# Processing Record 27 of Set 3 | natal
# Processing Record 28 of Set 3 | sankt polten
# Processing Record 29 of Set 3 | coihaique
# Processing Record 30 of Set 3 | bonavista
# Processing Record 31 of Set 3 | kracheh
# City not found. Skipping...
# Processing Record 32 of Set 3 | dorogobuzh
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | severo-kurilsk
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | bykivka
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | grindavik
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | daokou
# Processing Record 42 of Set 3 | aketi
# Processing Record 43 of Set 3 | cortes
# Processing Record 44 of Set 3 | igunga
# Processing Record 45 of Set 3 | otane
# Processing Record 46 of Set 3 | aliwal north
# Processing Record 47 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 3 | ibipeba
# Processing Record 49 of Set 3 | mantua
# Processing Record 50 of Set 3 | jati
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | buala
# Processing Record 4 of Set 4 | tubmanburg
# Processing Record 5 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 4 | roald
# Processing Record 7 of Set 4 | northam
# Processing Record 8 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 4 | senanga
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 4 | diego de almagro
# Processing Record 14 of Set 4 | denpasar
# Processing Record 15 of Set 4 | lompoc
# Processing Record 16 of Set 4 | hornepayne
# Processing Record 17 of Set 4 | staryy oskol
# Processing Record 18 of Set 4 | jatibonico
# Processing Record 19 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 4 | qui nhon
# Processing Record 21 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 4 | starotimoshkino
# Processing Record 23 of Set 4 | yar-sale
# Processing Record 24 of Set 4 | jiuquan
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | gigmoto
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | stepnyak
# Processing Record 29 of Set 4 | rawson
# Processing Record 30 of Set 4 | torzhok
# Processing Record 31 of Set 4 | guerrero negro
# Processing Record 32 of Set 4 | kota kinabalu
# Processing Record 33 of Set 4 | portland
# Processing Record 34 of Set 4 | kavaratti
# Processing Record 35 of Set 4 | plettenberg bay
# Processing Record 36 of Set 4 | kurilsk
# Processing Record 37 of Set 4 | alexandria
# Processing Record 38 of Set 4 | grand gaube
# Processing Record 39 of Set 4 | yashkul
# Processing Record 40 of Set 4 | mariental
# Processing Record 41 of Set 4 | axim
# Processing Record 42 of Set 4 | tessalit
# Processing Record 43 of Set 4 | vilyuysk
# Processing Record 44 of Set 4 | sandpoint
# Processing Record 45 of Set 4 | kloulklubed
# Processing Record 46 of Set 4 | kiunga
# Processing Record 47 of Set 4 | haines junction
# Processing Record 48 of Set 4 | okha
# Processing Record 49 of Set 4 | nome
# Processing Record 50 of Set 4 | vaini
# Processing Record 1 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 3 of Set 5 | kununurra
# Processing Record 4 of Set 5 | ust-maya
# Processing Record 5 of Set 5 | sayat
# Processing Record 6 of Set 5 | isla vista
# Processing Record 7 of Set 5 | saint peter
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | sola
# Processing Record 10 of Set 5 | sorland
# Processing Record 11 of Set 5 | la ronge
# Processing Record 12 of Set 5 | kalaleh
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | malakal
# Processing Record 16 of Set 5 | palmar de varela
# Processing Record 17 of Set 5 | half moon bay
# Processing Record 18 of Set 5 | airai
# Processing Record 19 of Set 5 | juniyah
# City not found. Skipping...
# Processing Record 20 of Set 5 | burica
# City not found. Skipping...
# Processing Record 21 of Set 5 | iwaki
# Processing Record 22 of Set 5 | yokadouma
# Processing Record 23 of Set 5 | tortoli
# Processing Record 24 of Set 5 | lerwick
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | el alto
# Processing Record 27 of Set 5 | udaipura
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | muros
# Processing Record 31 of Set 5 | kenora
# Processing Record 32 of Set 5 | yakima
# Processing Record 33 of Set 5 | erken-shakhar
# City not found. Skipping...
# Processing Record 34 of Set 5 | henties bay
# Processing Record 35 of Set 5 | severobaykalsk
# Processing Record 36 of Set 5 | saint-francois
# Processing Record 37 of Set 5 | kurchum
# Processing Record 38 of Set 5 | aykhal
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | jega
# Processing Record 41 of Set 5 | doha
# Processing Record 42 of Set 5 | tunggol
# Processing Record 43 of Set 5 | jalu
# Processing Record 44 of Set 5 | ginir
# Processing Record 45 of Set 5 | jackson
# Processing Record 46 of Set 5 | san nicolas
# Processing Record 47 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 5 | lavrentiya
# Processing Record 49 of Set 5 | chirongui
# Processing Record 50 of Set 5 | vardo
# Processing Record 1 of Set 6 | codrington
# Processing Record 2 of Set 6 | coahuayana
# Processing Record 3 of Set 6 | tiksi
# Processing Record 4 of Set 6 | valverde del camino
# Processing Record 5 of Set 6 | elban
# Processing Record 6 of Set 6 | uk
# City not found. Skipping...
# Processing Record 7 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 6 | saint-augustin
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | monzon
# Processing Record 11 of Set 6 | port alfred
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | caucaia
# Processing Record 15 of Set 6 | iskilip
# Processing Record 16 of Set 6 | ambon
# Processing Record 17 of Set 6 | cap-aux-meules
# Processing Record 18 of Set 6 | capaccio
# Processing Record 19 of Set 6 | chokurdakh
# Processing Record 20 of Set 6 | bambous virieux
# Processing Record 21 of Set 6 | saldanha
# Processing Record 22 of Set 6 | losal
# Processing Record 23 of Set 6 | georgiyevskoye
# Processing Record 24 of Set 6 | cartagena
# Processing Record 25 of Set 6 | faanui
# Processing Record 26 of Set 6 | cockburn town
# Processing Record 27 of Set 6 | saint anthony
# Processing Record 28 of Set 6 | shimoda
# Processing Record 29 of Set 6 | presidencia roque saenz pena
# Processing Record 30 of Set 6 | sabha
# Processing Record 31 of Set 6 | save
# Processing Record 32 of Set 6 | rudbar
# Processing Record 33 of Set 6 | bondo
# Processing Record 34 of Set 6 | trogir
# Processing Record 35 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 6 | kudahuvadhoo
# Processing Record 37 of Set 6 | mabaruma
# Processing Record 38 of Set 6 | aksu
# Processing Record 39 of Set 6 | torbay
# Processing Record 40 of Set 6 | lincoln
# Processing Record 41 of Set 6 | conde
# Processing Record 42 of Set 6 | tautira
# Processing Record 43 of Set 6 | poum
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | qaqortoq
# Processing Record 46 of Set 6 | puerto baquerizo moreno
# Processing Record 47 of Set 6 | neyshabur
# Processing Record 48 of Set 6 | broome
# Processing Record 49 of Set 6 | fort-shevchenko
# Processing Record 50 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 7 | butte
# Processing Record 2 of Set 7 | saint-pierre
# Processing Record 3 of Set 7 | olafsvik
# Processing Record 4 of Set 7 | khash
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | gulu
# Processing Record 8 of Set 7 | beisfjord
# Processing Record 9 of Set 7 | at-bashi
# Processing Record 10 of Set 7 | cabo san lucas
# Processing Record 11 of Set 7 | cochrane
# Processing Record 12 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 7 | cascais
# Processing Record 14 of Set 7 | saint-philippe
# Processing Record 15 of Set 7 | lufilufi
# Processing Record 16 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 7 | iqaluit
# Processing Record 18 of Set 7 | rach gia
# Processing Record 19 of Set 7 | victor harbor
# Processing Record 20 of Set 7 | panzhihua
# Processing Record 21 of Set 7 | tlahualilo
# City not found. Skipping...
# Processing Record 22 of Set 7 | kushiro
# Processing Record 23 of Set 7 | arkhipo-osipovka
# Processing Record 24 of Set 7 | ancud
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | neuquen
# Processing Record 27 of Set 7 | kuusamo
# Processing Record 28 of Set 7 | suntar
# Processing Record 29 of Set 7 | camacha
# Processing Record 30 of Set 7 | mezen
# Processing Record 31 of Set 7 | bandarbeyla
# Processing Record 32 of Set 7 | milkovo
# Processing Record 33 of Set 7 | dzilam gonzalez
# Processing Record 34 of Set 7 | yagoua
# Processing Record 35 of Set 7 | menongue
# Processing Record 36 of Set 7 | naze
# Processing Record 37 of Set 7 | phibun mangsahan
# Processing Record 38 of Set 7 | praia da vitoria
# Processing Record 39 of Set 7 | batsfjord
# Processing Record 40 of Set 7 | salisbury
# Processing Record 41 of Set 7 | seoul
# Processing Record 42 of Set 7 | huilong
# Processing Record 43 of Set 7 | marawi
# Processing Record 44 of Set 7 | contai
# Processing Record 45 of Set 7 | touros
# Processing Record 46 of Set 7 | mount isa
# Processing Record 47 of Set 7 | mayfield
# Processing Record 48 of Set 7 | avera
# Processing Record 49 of Set 7 | ballina
# Processing Record 50 of Set 7 | general pico
# Processing Record 1 of Set 8 | westport
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | tambilil
# Processing Record 4 of Set 8 | socorro
# Processing Record 5 of Set 8 | lebu
# Processing Record 6 of Set 8 | kotelnikovo
# Processing Record 7 of Set 8 | sampit
# Processing Record 8 of Set 8 | minyar
# Processing Record 9 of Set 8 | tual
# Processing Record 10 of Set 8 | midwest city
# Processing Record 11 of Set 8 | san andres
# Processing Record 12 of Set 8 | honjo
# Processing Record 13 of Set 8 | laguna
# Processing Record 14 of Set 8 | ha noi
# Processing Record 15 of Set 8 | la rioja
# Processing Record 16 of Set 8 | gornyy
# Processing Record 17 of Set 8 | los llanos de aridane
# Processing Record 18 of Set 8 | kelo
# Processing Record 19 of Set 8 | tazovskiy
# Processing Record 20 of Set 8 | talara
# Processing Record 21 of Set 8 | sinnamary
# Processing Record 22 of Set 8 | kampot
# Processing Record 23 of Set 8 | laukaa
# Processing Record 24 of Set 8 | labuhan
# Processing Record 25 of Set 8 | santa maria
# Processing Record 26 of Set 8 | sembe
# Processing Record 27 of Set 8 | lasa
# Processing Record 28 of Set 8 | matara
# Processing Record 29 of Set 8 | berlevag
# Processing Record 30 of Set 8 | port hedland
# Processing Record 31 of Set 8 | ugoofaaru
# Processing Record 32 of Set 8 | bansdih
# Processing Record 33 of Set 8 | longyearbyen
# Processing Record 34 of Set 8 | salta
# Processing Record 35 of Set 8 | botigues
# Processing Record 36 of Set 8 | nalut
# Processing Record 37 of Set 8 | isakly
# Processing Record 38 of Set 8 | banda aceh
# Processing Record 39 of Set 8 | carnarvon
# Processing Record 40 of Set 8 | staszow
# Processing Record 41 of Set 8 | san patricio
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | margate
# Processing Record 44 of Set 8 | yaan
# Processing Record 45 of Set 8 | byron bay
# Processing Record 46 of Set 8 | waipawa
# Processing Record 47 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 48 of Set 8 | san jose
# Processing Record 49 of Set 8 | narsaq
# Processing Record 50 of Set 8 | prykolotne
# Processing Record 1 of Set 9 | sechura
# Processing Record 2 of Set 9 | xinyang
# Processing Record 3 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 9 | amuntai
# Processing Record 5 of Set 9 | ullapool
# Processing Record 6 of Set 9 | high level
# Processing Record 7 of Set 9 | jakhal mandi
# City not found. Skipping...
# Processing Record 8 of Set 9 | luang prabang
# Processing Record 9 of Set 9 | luceville
# City not found. Skipping...
# Processing Record 10 of Set 9 | kathmandu
# Processing Record 11 of Set 9 | aklavik
# Processing Record 12 of Set 9 | kutum
# Processing Record 13 of Set 9 | claremont
# Processing Record 14 of Set 9 | iwanai
# Processing Record 15 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 9 | sitka
# Processing Record 17 of Set 9 | yuzhno-kurilsk
# Processing Record 18 of Set 9 | liwale
# Processing Record 19 of Set 9 | miyako
# Processing Record 20 of Set 9 | manoel urbano
# Processing Record 21 of Set 9 | shenxian
# Processing Record 22 of Set 9 | leningradskiy
# Processing Record 23 of Set 9 | itoman
# Processing Record 24 of Set 9 | chimoio
# Processing Record 25 of Set 9 | coalcoman
# City not found. Skipping...
# Processing Record 26 of Set 9 | stayner
# Processing Record 27 of Set 9 | lawton
# Processing Record 28 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | asadabad
# Processing Record 31 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 9 | kayerkan
# Processing Record 33 of Set 9 | itarema
# Processing Record 34 of Set 9 | evensk
# Processing Record 35 of Set 9 | lazdijai
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | oistins
# Processing Record 38 of Set 9 | college
# Processing Record 39 of Set 9 | kerchevskiy
# Processing Record 40 of Set 9 | kruisfontein
# Processing Record 41 of Set 9 | kihei
# Processing Record 42 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 43 of Set 9 | aykino
# Processing Record 44 of Set 9 | sammamish
# Processing Record 45 of Set 9 | predivinsk
# Processing Record 46 of Set 9 | rongcheng
# Processing Record 47 of Set 9 | kavieng
# Processing Record 48 of Set 9 | port hardy
# Processing Record 49 of Set 9 | kysyl-syr
# Processing Record 50 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 10 | kashi
# Processing Record 2 of Set 10 | jiexiu
# Processing Record 3 of Set 10 | nuuk
# Processing Record 4 of Set 10 | alugan
# Processing Record 5 of Set 10 | douentza
# Processing Record 6 of Set 10 | fukue
# Processing Record 7 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 10 | mahon
# Processing Record 9 of Set 10 | kedougou
# Processing Record 10 of Set 10 | beloha
# Processing Record 11 of Set 10 | jamiltepec
# Processing Record 12 of Set 10 | tondano
# Processing Record 13 of Set 10 | hearst
# Processing Record 14 of Set 10 | maua
# Processing Record 15 of Set 10 | waingapu
# Processing Record 16 of Set 10 | bambari
# Processing Record 17 of Set 10 | tungor
# Processing Record 18 of Set 10 | san juan de abajo
# Processing Record 19 of Set 10 | punta gorda
# Processing Record 20 of Set 10 | pisco
# Processing Record 21 of Set 10 | arlit
# Processing Record 22 of Set 10 | alakurtti
# Processing Record 23 of Set 10 | hasaki
# Processing Record 24 of Set 10 | nurota
# Processing Record 25 of Set 10 | oum hadjer
# Processing Record 26 of Set 10 | miquelon
# Processing Record 27 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 10 | ler
# Processing Record 29 of Set 10 | ola
# Processing Record 30 of Set 10 | dongsheng
# Processing Record 31 of Set 10 | nueva guinea
# Processing Record 32 of Set 10 | maputo
# Processing Record 33 of Set 10 | kristiansund
# Processing Record 34 of Set 10 | vila velha
# Processing Record 35 of Set 10 | jumla
# Processing Record 36 of Set 10 | surin
# Processing Record 37 of Set 10 | kabare
# Processing Record 38 of Set 10 | del carmen
# Processing Record 39 of Set 10 | bilma
# Processing Record 40 of Set 10 | abu dhabi
# Processing Record 41 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 10 | maniitsoq
# Processing Record 43 of Set 10 | kalmunai
# Processing Record 44 of Set 10 | krabi
# Processing Record 45 of Set 10 | san cristobal
# Processing Record 46 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 47 of Set 10 | mason city
# Processing Record 48 of Set 10 | husavik
# Processing Record 49 of Set 10 | belmonte
# Processing Record 50 of Set 10 | ilulissat
# Processing Record 1 of Set 11 | tonekabon
# Processing Record 2 of Set 11 | bud
# Processing Record 3 of Set 11 | alyangula
# Processing Record 4 of Set 11 | souillac
# Processing Record 5 of Set 11 | bor
# Processing Record 6 of Set 11 | huancabamba
# Processing Record 7 of Set 11 | beringovskiy
# Processing Record 8 of Set 11 | alta floresta
# Processing Record 9 of Set 11 | san jeronimo
# Processing Record 10 of Set 11 | mansa
# Processing Record 11 of Set 11 | lac du bonnet
# Processing Record 12 of Set 11 | harper
# Processing Record 13 of Set 11 | gien
# Processing Record 14 of Set 11 | biak
# Processing Record 15 of Set 11 | pemba
# Processing Record 16 of Set 11 | gat
# Processing Record 17 of Set 11 | pucara
# Processing Record 18 of Set 11 | leshukonskoye
# Processing Record 19 of Set 11 | ruwi
# Processing Record 20 of Set 11 | peniche
# Processing Record 21 of Set 11 | envira
# Processing Record 22 of Set 11 | lazaro cardenas
# Processing Record 23 of Set 11 | hutchinson
# Processing Record 24 of Set 11 | maceio
# Processing Record 25 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 26 of Set 11 | salalah
# Processing Record 27 of Set 11 | cayenne
# Processing Record 28 of Set 11 | bograd
# Processing Record 29 of Set 11 | djibo
# Processing Record 30 of Set 11 | bilibino
# Processing Record 31 of Set 11 | edd
# Processing Record 32 of Set 11 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 33 of Set 11 | mopti
# Processing Record 34 of Set 11 | pierre
# Processing Record 35 of Set 11 | po
# City not found. Skipping...
# Processing Record 36 of Set 11 | isangel
# Processing Record 37 of Set 11 | tombouctou
# Processing Record 38 of Set 11 | mnogovershinnyy
# Processing Record 39 of Set 11 | kushima
# Processing Record 40 of Set 11 | morondava
# Processing Record 41 of Set 11 | yeniseysk
# Processing Record 42 of Set 11 | vitimskiy
# City not found. Skipping...
# Processing Record 43 of Set 11 | asyut
# Processing Record 44 of Set 11 | alofi
# Processing Record 45 of Set 11 | tsiroanomandidy
# Processing Record 46 of Set 11 | keti bandar
# Processing Record 47 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 11 | rockland
# Processing Record 49 of Set 11 | deputatskiy
# Processing Record 50 of Set 11 | iranduba
# Processing Record 1 of Set 12 | cozumel
# Processing Record 2 of Set 12 | tiznit
# Processing Record 3 of Set 12 | samarai
# Processing Record 4 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 12 | vysotsk
# Processing Record 6 of Set 12 | stornoway
# Processing Record 7 of Set 12 | vuktyl
# Processing Record 8 of Set 12 | kadoma
# Processing Record 9 of Set 12 | tarko-sale
# Processing Record 10 of Set 12 | mamallapuram
# Processing Record 11 of Set 12 | humen
# Processing Record 12 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 12 | traralgon
# Processing Record 14 of Set 12 | tucuru
# Processing Record 15 of Set 12 | pangody
# Processing Record 16 of Set 12 | omboue
# Processing Record 17 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 12 | vanavara
# Processing Record 19 of Set 12 | boden
# Processing Record 20 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 21 of Set 12 | tura
# Processing Record 22 of Set 12 | bam
# Processing Record 23 of Set 12 | merauke
# Processing Record 24 of Set 12 | eureka
# Processing Record 25 of Set 12 | ixtapa
# Processing Record 26 of Set 12 | stephenville crossing
# Processing Record 27 of Set 12 | labrea
# Processing Record 28 of Set 12 | padang
# Processing Record 29 of Set 12 | xai-xai
# Processing Record 30 of Set 12 | kondinskoye
# Processing Record 31 of Set 12 | metlika
# Processing Record 32 of Set 12 | san angelo
# Processing Record 33 of Set 12 | pahrump
# Processing Record 34 of Set 12 | namatanai
# Processing Record 35 of Set 12 | ginda
# Processing Record 36 of Set 12 | havelock
# Processing Record 37 of Set 12 | durban
# Processing Record 38 of Set 12 | islamkot
# Processing Record 39 of Set 12 | puerto del rosario
# Processing Record 40 of Set 12 | richards bay
# Processing Record 41 of Set 12 | mian channun
# Processing Record 42 of Set 12 | kamenka
# Processing Record 43 of Set 12 | pital
# Processing Record 44 of Set 12 | valkeala
# Processing Record 45 of Set 12 | taunggyi
# Processing Record 46 of Set 12 | baracoa
# Processing Record 47 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 12 | buraydah
# Processing Record 49 of Set 12 | coquimbo
# Processing Record 50 of Set 12 | bagdarin
# Processing Record 1 of Set 13 | duncan
# Processing Record 2 of Set 13 | horki
# Processing Record 3 of Set 13 | sergeyevka
# Processing Record 4 of Set 13 | phuthaditjhaba
# Processing Record 5 of Set 13 | vila franca do campo
# Processing Record 6 of Set 13 | bundaberg
# Processing Record 7 of Set 13 | basco
# Processing Record 8 of Set 13 | vilhena
# Processing Record 9 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 13 | north bend
# Processing Record 11 of Set 13 | san carlos de bariloche
# Processing Record 12 of Set 13 | mehamn
# Processing Record 13 of Set 13 | katherine
# Processing Record 14 of Set 13 | kolno
# Processing Record 15 of Set 13 | kommunisticheskiy
# Processing Record 16 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 13 | bagado
# Processing Record 18 of Set 13 | eyl
# Processing Record 19 of Set 13 | royan
# Processing Record 20 of Set 13 | palmer
# Processing Record 21 of Set 13 | channel-port aux basques
# Processing Record 22 of Set 13 | mancora
# Processing Record 23 of Set 13 | joshimath
# Processing Record 24 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 13 | maltahohe
# Processing Record 26 of Set 13 | nuqui
# Processing Record 27 of Set 13 | turtas
# Processing Record 28 of Set 13 | abalak
# Processing Record 29 of Set 13 | whitehorse
# Processing Record 30 of Set 13 | zhongshu
# Processing Record 31 of Set 13 | rapid valley
# Processing Record 32 of Set 13 | alamosa
# Processing Record 33 of Set 13 | griffith
# Processing Record 34 of Set 13 | bekwai
# Processing Record 35 of Set 13 | stykkisholmur
# Processing Record 36 of Set 13 | sisimiut
# Processing Record 37 of Set 13 | chicama
# Processing Record 38 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 13 | podor
# Processing Record 40 of Set 13 | shache
# Processing Record 41 of Set 13 | saint-joseph
# Processing Record 42 of Set 13 | montlucon
# Processing Record 43 of Set 13 | sobolevo
# Processing Record 44 of Set 13 | praya
# Processing Record 45 of Set 13 | karratha
# Processing Record 46 of Set 13 | porto novo
# Processing Record 47 of Set 13 | champa
# Processing Record 48 of Set 13 | mahuva
# Processing Record 49 of Set 13 | kapit
# Processing Record 50 of Set 13 | kulebaki
# Processing Record 1 of Set 14 | khasan
# Processing Record 2 of Set 14 | ahipara
# Processing Record 3 of Set 14 | tahoua
# Processing Record 4 of Set 14 | dhanera
# Processing Record 5 of Set 14 | shahrud
# Processing Record 6 of Set 14 | nakhon thai
# Processing Record 7 of Set 14 | goure
# Processing Record 8 of Set 14 | jeremie
# Processing Record 9 of Set 14 | palana
# Processing Record 10 of Set 14 | port-gentil
# Processing Record 11 of Set 14 | leninsk
# Processing Record 12 of Set 14 | payson
# Processing Record 13 of Set 14 | bambanglipuro
# Processing Record 14 of Set 14 | clonakilty
# Processing Record 15 of Set 14 | san luis
# Processing Record 16 of Set 14 | walvis bay
# Processing Record 17 of Set 14 | popondetta
# Processing Record 18 of Set 14 | tsabong
# Processing Record 19 of Set 14 | kupang
# Processing Record 20 of Set 14 | santo augusto
# Processing Record 21 of Set 14 | bonnyville
# Processing Record 22 of Set 14 | houma
# Processing Record 23 of Set 14 | jutai
# Processing Record 24 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 14 | yatou
# Processing Record 26 of Set 14 | wanning
# Processing Record 27 of Set 14 | fonte boa
# Processing Record 28 of Set 14 | maneadero
# Processing Record 29 of Set 14 | farah
# Processing Record 30 of Set 14 | riyadh
# Processing Record 31 of Set 14 | meulaboh
# Processing Record 32 of Set 14 | kumluca
# Processing Record 33 of Set 14 | chapais
# Processing Record 34 of Set 14 | festus
# Processing Record 35 of Set 14 | morwa
# Processing Record 36 of Set 14 | guanica
# Processing Record 37 of Set 14 | hauterive
# Processing Record 38 of Set 14 | knysna
# Processing Record 39 of Set 14 | la asuncion
# Processing Record 40 of Set 14 | bukachacha
# Processing Record 41 of Set 14 | merrill
# Processing Record 42 of Set 14 | ustye
# Processing Record 43 of Set 14 | makokou
# Processing Record 44 of Set 14 | kumla
# Processing Record 45 of Set 14 | sur
# Processing Record 46 of Set 14 | akureyri
# Processing Record 47 of Set 14 | monster
# Processing Record 48 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 49 of Set 14 | guiren
# Processing Record 50 of Set 14 | sistranda
# Processing Record 1 of Set 15 | san policarpo
# Processing Record 2 of Set 15 | shelburne
# Processing Record 3 of Set 15 | mareeba
# Processing Record 4 of Set 15 | sioux lookout
# Processing Record 5 of Set 15 | vao
# Processing Record 6 of Set 15 | emerald
# Processing Record 7 of Set 15 | manokwari
# Processing Record 8 of Set 15 | borogontsy
# Processing Record 9 of Set 15 | marystown
# Processing Record 10 of Set 15 | mandan
# Processing Record 11 of Set 15 | beidao
# Processing Record 12 of Set 15 | katobu
# Processing Record 13 of Set 15 | moranbah
# Processing Record 14 of Set 15 | troitsko-pechorsk
# Processing Record 15 of Set 15 | batticaloa
# Processing Record 16 of Set 15 | mayo
# Processing Record 17 of Set 15 | nishihara
# Processing Record 18 of Set 15 | nelson bay
# Processing Record 19 of Set 15 | fort nelson
# Processing Record 20 of Set 15 | tucuman
# Processing Record 21 of Set 15 | kandla
# Processing Record 22 of Set 15 | mogadishu
# Processing Record 23 of Set 15 | porto walter
# Processing Record 24 of Set 15 | semnan
# Processing Record 25 of Set 15 | kenai
# Processing Record 26 of Set 15 | umm kaddadah
# Processing Record 27 of Set 15 | tilichiki
# Processing Record 28 of Set 15 | nemuro
# Processing Record 29 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 15 | rocha
# Processing Record 31 of Set 15 | iraray
# Processing Record 32 of Set 15 | lata
# Processing Record 33 of Set 15 | sesheke
# Processing Record 34 of Set 15 | capao bonito
# Processing Record 35 of Set 15 | juba
# Processing Record 36 of Set 15 | manglisi
# Processing Record 37 of Set 15 | novichikha
# Processing Record 38 of Set 15 | oyama
# Processing Record 39 of Set 15 | ust-kut
# Processing Record 40 of Set 15 | hamilton
# Processing Record 41 of Set 15 | najran
# Processing Record 42 of Set 15 | talas
# Processing Record 43 of Set 15 | urengoy
# Processing Record 44 of Set 15 | banjar
# Processing Record 45 of Set 15 | ust-nera
# Processing Record 46 of Set 15 | ordynskoye
# Processing Record 47 of Set 15 | ust-ilimsk
# Processing Record 48 of Set 15 | bat khela
# Processing Record 49 of Set 15 | khandyga
# Processing Record 50 of Set 15 | pallasovka
# Processing Record 1 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 16 | san marcos de colon
# Processing Record 3 of Set 16 | burgeo
# Processing Record 4 of Set 16 | dunedin
# Processing Record 5 of Set 16 | makakilo city
# Processing Record 6 of Set 16 | pemberton
# Processing Record 7 of Set 16 | mazyr
# Processing Record 8 of Set 16 | rapina
# Processing Record 9 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 16 | marzuq
# Processing Record 11 of Set 16 | barra do garcas
# Processing Record 12 of Set 16 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 16 | xichang
# Processing Record 14 of Set 16 | cornelio procopio
# Processing Record 15 of Set 16 | sangar
# Processing Record 16 of Set 16 | dutse
# Processing Record 17 of Set 16 | miyoshi
# Processing Record 18 of Set 16 | necochea
# Processing Record 19 of Set 16 | roberval
# Processing Record 20 of Set 16 | phalodi
# Processing Record 21 of Set 16 | ayan
# Processing Record 22 of Set 16 | vaitape
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 707

# %%
# 7. Add data to a new DataFrame
weather_data_df = pd.DataFrame(city_data)

# Reorder the columns to look like example

new_weather_order = ["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

weather_data_df = weather_data_df[new_weather_order]

weather_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Antofagasta -23.6500  -70.4000     58.28        79          11        6.04
# 1      Mildura -34.2000  142.1500     42.08        89           8       12.03
# 2    Jamestown  42.0970  -79.2353     84.06        52          75       18.41
# 3        Bluff -46.6000  168.3333     37.80        83          85        9.51
# 4   Georgetown   5.4112  100.3354     82.89        92          20        2.30
# 5       Atuona  -9.8000 -139.0333     77.56        72          15       15.64
# 6     Acapulco  16.8634  -99.8901     85.87        73          88        6.71
# 7       Barrow  71.2906 -156.7887     42.82        81          75       27.63
# 8    Ostrovnoy  68.0531   39.5131     54.23        82          95        5.08
# 9   Nanortalik  60.1432  -45.2371     50.31        76           2       12.88
#
#   Weather Description
# 0          few clouds
# 1           clear sky
# 2       broken clouds
# 3     overcast clouds
# 4          few clouds
# 5          few clouds
# 6     overcast clouds
# 7       broken clouds
# 8     overcast clouds
# 9           clear sky

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).

output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
